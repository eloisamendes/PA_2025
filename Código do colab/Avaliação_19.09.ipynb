# %% [markdown]
# Eloísa Mendes Nunes

# %% [markdown]
# 1)Crie um programa em python que imprima números pares
#
# a) Pedir o usuário para digitar uma lista com mínimo 10 números
#
# b) Criar uma nova somente com numeros pares
#
# c) Imprimir números pares

# %%
pares = []

for i in range (10):
    numeros = int(input("Digite 10 números no mínimo:"))
    if numeros % 2==0:
         pares.append(numeros)
print(pares)
# Out:
# Digite 10 números no mínimo: 1
# Digite 10 números no mínimo: 2
# Digite 10 números no mínimo: 3
# Digite 10 números no mínimo: 4
# Digite 10 números no mínimo: 5
# Digite 10 números no mínimo: 6
# Digite 10 números no mínimo: 7
# Digite 10 números no mínimo: 8
# Digite 10 números no mínimo: 9
# Digite 10 números no mínimo: 10
# [2, 4, 6, 8, 10]

# %% [markdown]
# 2)Crie um programa que conte quantas vezes cada palavra aparece em uma frase.
#
# Pedir ao usuário para digitar uma frase. Imprimir a palavra e quantas vezes ela aparece

# %%
frase = input("Digite a sua frase:").lower()
palavras = frase.split()
contador = {}

for palavra in palavras:
    if palavra in contador:
        contador[palavra]+=1
    else:
        contador[palavra]=1
print("Contagem das palavras:")
for palavra, quantidade in contador.items():
    print(f"{palavra} :{quantidade}")
# Out:
# Digite a sua frase: Eu gosto de sorvete e eu também gosto de açaí
# Contagem das palavras:
# eu :2
# gosto :2
# de :2
# sorvete :1
# e :1
# também :1
# açaí :1

# %% [markdown]
# 3)Crie um programa em Python para avaliar um desfile de candidatas. O programa deve:
#
# a) Perguntar quantas candidatas vão participar.
#
# b) Perguntar o nome de cada candidata.
#
# c) Para cada candidata, receber 3 notas (uma de cada jurado).
#
# d) Somar as notas e guardar o total em um dicionário, onde a chave é o nome da candidata e o valor é a soma das notas.
#
# Mostrar ao final:
#
# a) A pontuação total de cada candidata.
#
# b) O nome da vencedora (a que tiver a maior pontuação).

# %%
qtd = int(input("Quantas vão participar?"))
notas = {}

for i in range(qtd):
    nome = input(f"\nDigite o nome da {i+1} candidata:")
    total = 0 

    for j in range(3):
        nota = int(input(f"Digite a nota dos jurados {j+1} para {nome}:"))
        total += nota
        
    notas [nome] = total
        
print("\nRESULTADOS:")

for candidata, ponto in notas.items():
    print(f"{candidata} = {ponto} pontos")

vencedora = max(notas, key=notas.get)
print(f"\nA vencedora é: {vencedora} com {notas[vencedora]} pontos!")
# Out:
# Quantas vão participar? 2
#
# Digite o nome da 1 candidata: Eloisa
# Digite a nota dos jurados 1 para Eloisa: 10
# Digite a nota dos jurados 2 para Eloisa: 10
# Digite a nota dos jurados 3 para Eloisa: 10
#
# Digite o nome da 2 candidata: Eduarda
# Digite a nota dos jurados 1 para Eduarda: 10
# Digite a nota dos jurados 2 para Eduarda: 9
# Digite a nota dos jurados 3 para Eduarda: 10
# RESULTADOS:
# Eloisa = 30 pontos
# Eduarda = 29 pontos
#
# A vencedora é: Eloisa com 30 pontos!
