# %% [markdown]
# <a href="https://colab.research.google.com/github/eloisamendes/PA_2025/blob/main/Aula_de_Operadores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l = 4
a = l*l
print (" A area do quadrado é igual a 16")
# Out:
#  A area do quadrado é igual a 16

# %%
a= l**2
print (a)
# Out:
# 16

# %% [markdown]
# # Soma

# %%
2+9
# Out:
# 11

# %% [markdown]
# # Subtração

# %%
9-4
# Out:
# 5

# %% [markdown]
# # Multiplicação

# %%
5*6
# Out:
# 30

# %% [markdown]
# # Divisão

# %%
4/5
# Out:
# 0.8

# %% [markdown]
# # Igualdade

# %%
a = 4
a==3
# Out:
# False

# %% [markdown]
# # Expoente

# %%
4**3
# Out:
# 64

# %% [markdown]
# # Maior, menor, maior ou igual e menor ou igual

# %%
5>2
# Out:
# True

# %%
5>6
# Out:
# False

# %%
5<6
# Out:
# True

# %%
5<4
# Out:
# False

# %%
5>=5
# Out:
# True

# %%
5<=5
# Out:
# True

# %%
5-6+8+15*(6/2)+4-9
# Out:
# 47.0

# %% [markdown]
# # Diferente

# %%
a!=4
# Out:
# False

# %% [markdown]
# # Variaveis

# %%
nome ='Eloisa'
sobrenome = 'Mendes'

print ('Meu nome é' + ' ' +  nome + ' ' + '' +sobrenome)
# Out:
# Meu nome é Eloisa Mendes

# %%
nome1 = str(input('Digite seu nome: '))
sobrenome1 = str(input( 'Digite seu sobrenome: ' ))

print ('Meu nome é ' + nome1 + ' ' + sobrenome1)
# Out:
# Digite seu nome: eloisa
# Digite seu sobrenome: mendes
# Meu nome é eloisa mendes

# %%
print (nome)
# Out:
# Eloisa

# %%
print (sobrenome)

# %%
#entrada
lado = float(input('Digite o lado do quadrado: '))
#processamento
area = lado * lado
#saida

print('o resultado é ' , area)
# Out:
# Digite o lado do quadrado: 3.5
# o resultado é  12.25
